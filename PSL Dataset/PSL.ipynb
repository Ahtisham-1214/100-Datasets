# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\ahtis\\100-Datasets\\PSL Dataset\\PSL.csv") # change it accordingly
df.shape
# Out:
# (81, 14)

# %%
df.tail(50)
# Out:
#                 Team1              Team2  Team1 Score  Team2 Score  \
# 31     Peshawar Zalmi  Quetta Gladiators          117            0
# 32      Karachi Kings   Islamabad United           90           75
# 33  Quetta Gladiators   Lahore Qalandars          200          202
# 34   Islamabad United     Peshawar Zalmi          136          137
# 35     Peshawar Zalmi      Karachi Kings          174          165
# 36   Lahore Qalandars   Islamabad United          145          146
# 37      Karachi Kings  Quetta Gladiators          154          158
# 38     Peshawar Zalmi   Lahore Qalandars          166          149
# 39  Quetta Gladiators   Islamabad United          165          164
# 40   Lahore Qalandars      Karachi Kings          155          158
# 41     Peshawar Zalmi  Quetta Gladiators          128          130
# 42      Karachi Kings   Islamabad United          123          127
# 43     Peshawar Zalmi  Quetta Gladiators          200          199
# ...
